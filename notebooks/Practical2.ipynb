# %% [markdown]
# ## A feladatok megoldása során csak a random, typing, math és pyerf modulok importálása elfogadott

# %% [markdown]
# ### A véletlenszám generálással kapcsolatos feladatok megoldását mentse src/utils modul-ba a **rand_wrappers.py** nevű fájlba

# %% [markdown]
# #### I. Véletlenszám generálás

# %%
"""
0. Importáld a random modult
"""

# %%
import random

# %%
"""
 1., Hívd meg a random szám generátort, és generálj egy 0 és 1 közötti véletlen számot
"""

# %%
import random
y = random.random()
print(y)
# Out:
# 0.6376377860886175

# %%
"""
2., Generálj 1 és 100 közötti egész véletlen számokat
"""

# %%
import random
gen = random.randint(1, 100)
print(gen)
# Out:
# 29

# %%
"""
3. Generálj 1 és 100 közötti véletlen egész számot, olyan módon, hogy a random seed értéke 42 legyen
"""

# %%
import random
random.seed(42) # beállítjuk a random seed értékét 42-re
n = random.randint(1, 100) # generálunk egy véletlen egész számot 1 és 100 között
print(n)
# Out:
# 82

# %%
"""
4., Készíts egy függvényt, ami visszaad egy véletlenül kiválasztott elemet egy egész számokat tartalmazó listából.
    függvény neve: random_from_list
    bemenet: input_list
    kimenetí típus: int
"""

# %%
import random

def random_from_list(input_list):
    # ellenőrizzük, hogy a bemenet egy nem üres lista-e
    if isinstance(input_list, list) and len(input_list) > 0:
        # visszaadjuk a listából véletlenül kiválasztott elemet
        return random.choice(input_list)
    else:
        # hibát dobunk, ha a bemenet nem megfelelő
        raise ValueError("A bemenetnek egy nem üres lista kell lennie.")

# %%
my_list = [1, 2, 3, 4, 5]
result = random_from_list(my_list)
print(result)
# Out:
# 3

# %%
"""
5., Készíts egy függvényt, ami visszaad egy n darab véletlen számot tartalmazó listát egy egész számokat tartalmazó bemenenti listából.
    függvény neve: random_sublist_from_list
    bemenet: input_list, number_of_elements
    kimenetí típus: List
"""

# %%
import random
def random_sublist_from_list(input_list, number_of_elements):
    # ellenőrizzük, hogy a bemenetek megfelelőek-e
    if isinstance(input_list, list) and isinstance(number_of_elements, int):
        # ellenőrizzük, hogy a bemeneti lista nem üres-e
        if len(input_list) > 0:
            # ellenőrizzük, hogy a kiválasztandó elemek száma nem nagyobb-e, mint a bemeneti lista hossza
            if number_of_elements <= len(input_list):
                # visszaadjuk a listából véletlenül kiválasztott n darab elemet tartalmazó listát
                return random.sample(input_list, number_of_elements)
            else:
                # hibát dobunk, ha a kiválasztandó elemek száma túl nagy
                raise ValueError("A kiválasztandó elemek száma nem lehet nagyobb, mint a bemeneti lista hossza.")
        else:
            # hibát dobunk, ha a bemeneti lista üres
            raise ValueError("A bemeneti lista nem lehet üres.")
    else:
        # hibát dobunk, ha a bemenetek nem megfelelő típusúak
        raise TypeError("A bemenetnek egy lista és egy egész szám kell lennie.")

# %%
my_list = [1, 2, 3, 4, 5]
result = random_sublist_from_list(my_list, 3)
print(result)
# Out:
# [2, 5, 1]

# %%
"""
6., Készíts egy függvényt, ami visszaad egy véletlenül kiválasztott elemet egy string-ből.
    függvény neve: random_from_string
    bemenet: input_string
    kimeneti típus: string
"""

# %%
import random
def random_from_string(input_string):
    # ellenőrizzük, hogy a bemenet egy string-e
    if isinstance(input_string, str):
        # ellenőrizzük, hogy a bemeneti string nem üres-e
        if len(input_string) > 0:
            # visszaadjuk a stringből véletlenül kiválasztott karaktert
            return random.choice(input_string)
        else:
            # hibát dobunk, ha a bemeneti string üres
            raise ValueError("A bemeneti string nem lehet üres.")
    else:
        # hibát dobunk, ha a bemenet nem string
        raise TypeError("A bemenetnek egy stringnek kell lennie.")

# %%
my_string = "hello"
result = random_from_string(my_string)
print(result)
# Out:
# o

# %%
'''
7., Készíts egy függvényt, amely visszaad egy 100 elemű, 0 és 1 közötti véletlen számokat tartalmazó listát
    függvény név: hundred_small_random
    bemenet: None
    kimeneti típus: List
'''

# %%
import random
def hundred_small_random():
    # létrehozunk egy üres listát
    output_list = []
    # 100-szor ismételjük a következőt
    for i in range(100):
        # generálunk egy véletlen számot 0 és 1 között
        x = random.uniform(0, 1)
        # hozzáadjuk a számot a listához
        output_list.append(x)
    # visszaadjuk a listát
    return output_list

# %%
result = hundred_small_random()
print(result)
# Out:
# [0.08693883262941615, 0.4219218196852704, 0.029797219438070344, 0.21863797480360336, 0.5053552881033624, 0.026535969683863625, 0.1988376506866485, 0.6498844377795232, 0.5449414806032167, 0.2204406220406967, 0.5892656838759087, 0.8094304566778266, 0.006498759678061017, 0.8058192518328079, 0.6981393949882269, 0.3402505165179919, 0.15547949981178155, 0.9572130722067812, 0.33659454511262676, 0.09274584338014791, 0.09671637683346401, 0.8474943663474598, 0.6037260313668911, 0.8071282732743802, 0.7297317866938179, 0.5362280914547007, 0.9731157639793706, 0.3785343772083535, 0.552040631273227, 0.8294046642529949, 0.6185197523642461, 0.8617069003107772, 0.577352145256762, 0.7045718362149235, 0.045824383655662215, 0.22789827565154686, 0.28938796360210717, 0.0797919769236275, 0.23279088636103018, 0.10100142940972912, 0.2779736031100921, 0.6356844442644002, 0.36483217897008424, 0.37018096711688264, 0.2095070307714877, 0.26697782204911336, 0.936654587712494, 0.6480353852465935, 0.6091310056669882,
# ...

# %%
"""
8., Készíts egy függvényt, amely visszaad egy 100 elemű, 10 és 1000 közötti véletlen számokat tartalmazó listát
    függvény név: hundred_large_random
    bemenet: None
    kimeneti típus: List
"""

# %%
import random
def hundred_large_random():
    # létrehozunk egy üres listát
    output_list = []
    # 100-szor ismételjük a következőt
    for i in range(100):
        # generálunk egy véletlen számot 10 és 1000 között
        x = random.randint(10, 1000)
        # hozzáadjuk a számot a listához
        output_list.append(x)
    # visszaadjuk a listát
    return output_list

# %%
result = hundred_large_random()
print(result)
# Out:
# [455, 171, 474, 13, 986, 749, 906, 746, 279, 522, 790, 192, 529, 944, 118, 901, 650, 315, 871, 664, 529, 633, 213, 166, 392, 790, 175, 562, 986, 807, 954, 553, 950, 10, 623, 341, 510, 29, 124, 961, 381, 909, 861, 836, 324, 255, 69, 256, 909, 590, 979, 90, 97, 759, 507, 845, 80, 788, 555, 794, 138, 141, 685, 496, 979, 572, 179, 281, 550, 903, 631, 443, 997, 226, 961, 562, 783, 757, 716, 215, 740, 329, 418, 697, 675, 392, 458, 931, 539, 472, 133, 263, 240, 75, 356, 31, 612, 577, 245, 612]

# %%
"""
9., Készíts egy függvényt, amely visszaad 5 elemű, 9 és 1000 közötti, 3-al osztható egész számokat tartalmazó listát
    függvény név: five_random_number_div_three
    bemenet: None
    kimeneti típus: List

"""

# %%
import random
def five_random_number_div_three():
    # létrehozunk egy üres listát
    output_list = []
    # 5-ször ismételjük a következőt
    for i in range(5):
        # generálunk egy véletlen számot 9 és 1000 között, 3-al osztható
        x = random.randrange(9, 1000, 3)
        # hozzáadjuk a számot a listához
        output_list.append(x)
    # visszaadjuk a listát
    return output_list

# %%
result = five_random_number_div_three()
print(result)
# Out:
# [345, 18, 117, 978, 99]

# %%
"""
10., Készíts egy függvényt amely a bemeneti lista elemeit véletlenszerűen összekeveri
    függvény név: random_reorder
    bemenet: input_list
    kimeneti típus: List
"""

# %%
import random
def random_reorder(input_list):
    # ellenőrizzük, hogy a bemenet egy lista-e
    if isinstance(input_list, list):
        # másoljuk a bemeneti listát, hogy ne változtassuk meg az eredetit
        output_list = input_list.copy()
        # összekeverjük a lista elemeit
        random.shuffle(output_list)
        # visszaadjuk az összekevert listát
        return output_list
    else:
        # hibát dobunk, ha a bemenet nem lista
        raise TypeError("A bemenetnek egy listának kell lennie.")

# %%
my_list = [1, 2, 3, 4, 5]
result = random_reorder(my_list)
print(result)
# Out:
# [5, 3, 4, 2, 1]

# %%
"""
11., Készíts egy függvényt, amely 1 és 5 közötti egyenletes eloszlású valós véletlen számot ad vissza minden meghívás esetén.
    függvény név: uniform_one_to_five
    bemenet: None
    kimeneti típus: float
"""

# %%
import random
def uniform_one_to_five():
    # generálunk egy véletlen számot 1 és 5 között, egyenletes eloszlásban
    x = random.uniform(1, 5)
    # visszaadjuk a számot
    return x

# %%
result = uniform_one_to_five()
print(result)
# Out:
# 1.5292473949001

# %% [markdown]
# ### Az eloszlásokkal kapcsolatos feladatok megoldását mentse src/utils modul-ba a distributions.py nevű fájlba

# %% [markdown]
# #### II. Eloszlások

# %%
"""
1., Hozz létre egy új osztályt, aminek a neve FirstClass
    osztály név: FirstClass
"""

# %%
class FirstClass:
    def __init__(self):
        pass

# Példa az osztály használatára:
first_obj = FirstClass()  # Példány létrehozása a FirstClass osztályból

# %%
"""
2., Hozz létre egy új osztályt, aminek a neve SecondClass, és definiáljon benne egy __init__ nevű függvényt, amely bead egy véletlenszám generátort a self.random adattagnak.
    Osztály név: SecondClass
    függvény név: __init__
    bemenet: self, rand
"""

# %%
import random
import random

class SecondClass:
    def __init__(self, rand):
        self.random = rand

# Példa az osztály használatára:
# Hozzunk létre egy véletlenszám generátort és adjuk át a SecondClass példánynak
random_generator = random.Random()  # Véletlenszám generátor példányosítása
second_obj = SecondClass(random_generator)
# Most az objektum hozzáfér a véletlenszám generátorhoz az self.random segítségével

# %%
"""
3., Hozzan létre egy új osztályt aminek a neve UniformDistribution. Definiáljon benne a __init__ nevű függvényt, amelynek bemenetként kap egy véletlenszám generátort, és az eloszlás alsó (a) és felső határát (b), amely értékeket adattagokba ment le.
    Osztály név: UniformDistribution
    függvény név: __init__
    bemenet: self, rand, a, b
"""
import random

class UniformDistribution:
    def __init__(self, rand, a, b):
        self.rand = rand
        self.a = a
        self.b = b

    def generate_random(self):
        # Generálunk egy véletlenszámot az [a, b] tartományban
        return self.rand.uniform(self.a, self.b)

# Példa az osztály használatára:
# Hozzunk létre egy példányt a UniformDistribution osztályból
random_generator = random.Random()  # Véletlenszám generátor példányosítása
a = 1.0
b = 10.0
uniform_dist = UniformDistribution(random_generator, a, b)
# Generáljunk egy véletlenszámot az [a, b] tartományban
random_number = uniform_dist.generate_random()
print(f'Generált véletlenszám az [{a}, {b}] tartományban: {random_number}')

class UniformDistribution:
    def __init__(self, rand, a, b):
        self.rand = rand
        self.a = a
        self.b = b

    def next(self):
        return self.rand.uniform(self.a, self.b)
    
    import random

rand = random.Random()

distribution = UniformDistribution(rand, 0, 10)

print(distribution.next())
"""
4., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely a és b pont közötti értékekhez a hozzájuk tartozó egyenletes eloszlás, eloszlás függvényében hozzárendelt értékét rendeli.
    függvény név: pdf
    bemenet: x
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def pdf(self, x):
        if x < self.a or x > self.b:
            return 0.0
        else:
            return 1.0 / (self.b - self.a)

# Teszteljük az osztályt
a = 1.0
b = 5.0
uniform_dist = UniformDistribution(a, b)

x_values = [0.0, 2.0, 3.0, 6.0]
for x in x_values:
    pdf_value = uniform_dist.pdf(x)
    print(f'pdf({x}) = {pdf_value}')



"""
5., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely megvalósítja az egyenletes eloszlás kumulatív eloszlás függvényét.
    függvény név: cdf
    bemenet: x
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
    
    p = 0.5  # Például számoljuk ki a 0.5 inverz kumulatív eloszlását
    result_ppf = uniform.ppf(p)
    print(f"A(z) {p}-hez tartozó inverz kumulatív eloszlás: {result_ppf}")
    
    x = 0.7  # Például számoljuk ki a 0.7 kumulatív eloszlásértéket
    result_cdf = uniform.cdf(x)
    print(f"A(z) {x}-hez tartozó kumulatív eloszlás: {result_cdf}")


"""
6., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely implementálja az egyenletes eloszlás inverz kumulatív eloszlás függvényét. (percent-point function)
    függvény név: ppf
    bemenet: p
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
    p = 0.5  # Például számoljuk ki a 0.5 inverz kumulatív eloszlását
    result = uniform.ppf(p)
    print(f"A(z) {p}-hez tartozó inverz kumulatív eloszlás: {result}")

"""
7., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely az osztály létrehozásánál megadott paraméterek mellett, egyenletes eloszlású véletlen számokat generál minden meghívásnál.
    függvény név: gen_random
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution

"""
import random

class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

    def gen_random(self):
        return random.uniform(self.a, self.b)

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
    
    p = 0.5  # Például számoljuk ki a 0.5 inverz kumulatív eloszlását
    result_ppf = uniform.ppf(p)
    print(f"A(z) {p}-hez tartozó inverz kumulatív eloszlás: {result_ppf}")
    
    x = 0.7  # Például számoljuk ki a 0.7 kumulatív eloszlásértéket
    result_cdf = uniform.cdf(x)
    print(f"A(z) {x}-hez tartozó kumulatív eloszlás: {result_cdf}")
    
    random_number = uniform.gen_random()
    print(f"Egyenletes eloszlású véletlen szám: {random_number}")
"""
8., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény átlagát.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: mean
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

    def gen_random(self):
        return random.uniform(self.a, self.b)

    def mean(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return (self.a + self.b) / 2

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
    
    mean = uniform.mean()
    print(f"Az eloszlás átlaga: {mean}")

"""
9., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény mediánját.
    függvény név: median
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

    def gen_random(self):
        return random.uniform(self.a, self.b)

    def mean(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return (self.a + self.b) / 2

    def median(self):
        return self.mean()  # A medián mindig az átlag, vagyis a középpont

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
  
    median = uniform.median()
    print(f"Az eloszlás mediánja: {median}")

"""
10., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény varianciáját.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: variance
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

    def gen_random(self):
        return random.uniform(self.a, self.b)

    def mean(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return (self.a + self.b) / 2

    def median(self):
        return self.mean()

    def variance(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return ((self.b - self.a) ** 2) / 12.0

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
    
    variance = uniform.variance()
    print(f"Az eloszlás varianciája: {variance}")

"""
11., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény ferdeségét.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: skewness
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

    def gen_random(self):
        return random.uniform(self.a, self.b)

    def mean(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return (self.a + self.b) / 2

    def median(self):
        return self.mean()

    def variance(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return ((self.b - self.a) ** 2) / 12.0

    def skewness(self):
        return 0.0  # Az egyenletes eloszlás ferdesége mindig 0

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
    
    p = 0.5  # Például számoljuk ki a 0.5 inverz kumulatív eloszlását
    result_ppf = uniform.ppf(p)
    print(f"A(z) {p}-hez tartozó inverz kumulatív eloszlás: {result_ppf}")
    
    x = 0.7  # Például számoljuk ki a 0.7 kumulatív eloszlásértéket
    result_cdf = uniform.cdf(x)
    print(f"A(z) {x}-hez tartozó kumulatív eloszlás: {result_cdf}")
    
    random_number = uniform.gen_random()
    print(f"Egyenletes eloszlású véletlen szám: {random_number}")
    
    mean = uniform.mean()
    print(f"Az eloszlás átlaga: {mean}")
    
    median = uniform.median()
    print(f"Az eloszlás mediánja: {median}")
    
    variance = uniform.variance()
    print(f"Az eloszlás varianciája: {variance}")
    
    skewness = uniform.skewness()
    print(f"Az eloszlás ferdesége: {skewness}")


"""
12., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény többlet csúcsosságát.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: ex_kurtosis
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

    def gen_random(self):
        return random.uniform(self.a, self.b)

    def mean(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return (self.a + self.b) / 2

    def median(self):
        return self.mean()

    def variance(self):
        if self.a == self.b:
            raise Exception("Moment undefined")
        return ((self.b - self.a) ** 2) / 12.0

    def skewness(self):
        return 0.0  # Az egyenletes eloszlás ferdesége mindig 0

    def ex_kurtosis(self):
        return -6/5  # Az egyenletes eloszlás többlet csúcsossága mindig -6/5

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
        
    ex_kurtosis = uniform.ex_kurtosis()
    print(f"Az eloszlás többlet csúcsossága: {ex_kurtosis}")

"""
13., Egészítse ki a UniformDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény első 3 cetrális momentumát és a többlet csúcsosságot.  Ha az eloszlásnak nincsenek ilyen értékei, akkor return helyett hívja meg a raise Exception("Moments undefined") parancsot.
    függvény név: mvsk
    bemenet: None
    kimeneti típus: List
    link: https://en.wikipedia.org/wiki/Continuous_uniform_distribution
"""
class UniformDistribution:
    def __init__(self, a, b):
        self.a = a  # Alsó határ
        self.b = b  # Felső határ

    def ppf(self, p):
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        result = self.a + p * (self.b - self.a)
        return result

    def cdf(self, x):
        if x < self.a:
            return 0.0
        elif x >= self.b:
            return 1.0
        else:
            return (x - self.a) / (self.b - self.a)

    def gen_random(self):
        return random.uniform(self.a, self.b)

    def mean(self):
        if self.a == self.b:
            raise Exception("Moments undefined")
        return (self.a + self.b) / 2

    def median(self):
        return self.mean()

    def variance(self):
        if self.a == self.b:
            raise Exception("Moments undefined")
        return ((self.b - self.a) ** 2) / 12.0

    def skewness(self):
        return 0.0  # Az egyenletes eloszlás ferdesége mindig 0

    def ex_kurtosis(self):
        return -6/5  # Az egyenletes eloszlás többlet csúcsossága mindig -6/5

    def mvsk(self):
        if self.a == self.b:
            raise Exception("Moments undefined")
        return [self.mean(), self.variance(), self.skewness(), self.ex_kurtosis()]

# Tesztelés
if __name__ == "__main__":
    uniform = UniformDistribution(0, 1)
    
    p = 0.5  # Például számoljuk ki a 0.5 inverz kumulatív eloszlását
    result_ppf = uniform.ppf(p)
    print(f"A(z) {p}-hez tartozó inverz kumulatív eloszlás: {result_ppf}")
    
    x = 0.7  # Például számoljuk ki a 0.7 kumulatív eloszlásértéket
    result_cdf = uniform.cdf(x)
    print(f"A(z) {x}-hez tartozó kumulatív eloszlás: {result_cdf}")
    
    random_number = uniform.gen_random()
    print(f"Egyenletes eloszlású véletlen szám: {random_number}")
    
    mean = uniform.mean()
    print(f"Az eloszlás átlaga: {mean}")
    
    median = uniform.median()
    print(f"Az eloszlás mediánja: {median}")
    
    variance = uniform.variance()
    print(f"Az eloszlás varianciája: {variance}")
    
    skewness = uniform.skewness()
    print(f"Az eloszlás ferdesége: {skewness}")
    
    ex_kurtosis = uniform.ex_kurtosis()
    print(f"Az eloszlás többlet csúcsossága: {ex_kurtosis}")
    
    moments = uniform.mvsk()
    print(f"Az eloszlás első 3 centrális momentumai és többlet csúcsossága: {moments}")
# Out:
# Generált véletlenszám az [1.0, 10.0] tartományban: 2.1715805175911065
# 2.435378662693509
# pdf(0.0) = 0.0
# pdf(2.0) = 0.25
# pdf(3.0) = 0.25
# pdf(6.0) = 0.0
# A(z) 0.5-hez tartozó inverz kumulatív eloszlás: 0.5
# A(z) 0.7-hez tartozó kumulatív eloszlás: 0.7
# A(z) 0.5-hez tartozó inverz kumulatív eloszlás: 0.5
# A(z) 0.5-hez tartozó inverz kumulatív eloszlás: 0.5
# A(z) 0.7-hez tartozó kumulatív eloszlás: 0.7
# Egyenletes eloszlású véletlen szám: 0.2498064478821005
# Az eloszlás átlaga: 0.5
# Az eloszlás mediánja: 0.5
# Az eloszlás varianciája: 0.08333333333333333
# A(z) 0.5-hez tartozó inverz kumulatív eloszlás: 0.5
# A(z) 0.7-hez tartozó kumulatív eloszlás: 0.7
# Egyenletes eloszlású véletlen szám: 0.9232655992760128
# Az eloszlás átlaga: 0.5
# Az eloszlás mediánja: 0.5
# Az eloszlás varianciája: 0.08333333333333333
# Az eloszlás ferdesége: 0.0
# Az eloszlás többlet csúcsossága: -1.2
# A(z) 0.5-hez tartozó inverz kumulatív eloszlás: 0.5
# ...

# %%
"""
14., Hozzan létre egy új osztályt aminek a neve NormalDistribution. Definiáljon benne a __init__ nevű függvényt, amelynek bemenetként kap egy véletlenszám generátort, és az eloszlás várható értékét (location) és varianciáját (scale), amely értékeket adattagokba ment le.
    Osztály név: NormalDistribution
    függvény név: __init__
    bemenet: self, rand, loc, scale
"""
import random

class NormalDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)
# Példa használat
if __name__ == "__main__":
    # Inicializáljuk a véletlenszám generátort
    rand = random.Random()
    
    # Létrehozzuk a normál eloszlást
    normal_dist = NormalDistribution(rand, loc=0, scale=1)
    
    # Most már a normal_dist objektum tartalmazza a megadott paramétereket
    print("Várható érték:", normal_dist.loc)
    print("Szórás:", normal_dist.scale)

"""
15., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely loc várható értékű és scale varianciájú normális eloszlás eloszlásfüggvényéből rendel valószínűségi értéket a bemeneti x valós számhoz.
    függvény név: pdf
    bemenet: x
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import math

class NormalDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

# Tesztelés
if __name__ == "__main__":
    rand = None  # Véletlenszám generátor inicializálása, az Ön alkalmazásában itt valósulna meg
    loc = 0  # Várható érték
    scale = 1  # Szórás
    
    normal_dist = NormalDistribution(rand, loc, scale)
    
    x = 1  # Teszteljük a pdf függvényt ezzel az értékkel
    probability_density = normal_dist.pdf(x)
    print(f"Az x={x} értékhez tartozó valószínűségi sűrűség: {probability_density}")

"""
16., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely megvalósítja az eloszlás kumulatív eloszlás függvényét.
    függvény név: cdf
    bemenet: x
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import math

class NormalDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc  # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # A normális eloszlás valószínűségi sűrűségfüggvénye (PDF) képlete
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        normalization = 1 / (self.scale * math.sqrt(2 * math.pi))
        probability_density = normalization * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # A normális eloszlás kumulatív eloszlásfüggvénye (CDF) számítása
        z = (x - self.loc) / (self.scale * math.sqrt(2))
        cumulative_probability = (1 + math.erf(z)) / 2
        return cumulative_probability

# Tesztelés
if __name__ == "__main__":
    # Példa egy véletlenszám generátor létrehozására (random.Random használata)
    random_generator = random.Random()
    
    # Példa egy Normális eloszlás objektum létrehozására
    normal_dist = NormalDistribution(random_generator, loc=0, scale=1)
    
    # Tesztelés a cdf függvénnyel
    x = 1.0
    cdf_value = normal_dist.cdf(x)
    print(f"A kumulatív eloszlás értéke x={x} esetén: {cdf_value}")
    
"""
17., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely implementálja az eloszlás inverz kumulatív eloszlás függvényét
    függvény név: ppf
    bemenet: p
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""    
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Az inverz kumulatív eloszlásfüggvény tesztelése
    probabilities = [0.7,]
    for p in probabilities:
        x = normal_dist.ppf(p)
        print(f"Kvantilis a(z) p={p} esetén: {x}")
"""
18., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely az osztály létrehozásánál megadott paraméterek mellett, normális eloszlású véletlen számokat generál minden meghívásnál
    függvény név: gen_random
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution

"""
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

    def gen_random(self):
        # Generálunk egy normális eloszlású véletlen számot
        random_number = stats.norm.rvs(loc=self.loc, scale=self.scale)
        return random_number

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Normális eloszlású véletlen szám generálása
    random_number = normal_dist.gen_random()
    print(f"Normális eloszlású véletlen szám: {random_number}")

"""
19., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény átlagát.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: mean
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        return self.loc

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Az eloszlásfüggvény átlagának lekérdezése
    distribution_mean = normal_dist.mean()
    print(f"Az eloszlás átlaga: {distribution_mean}")

"""
20., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény mediánját
    függvény név: median
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        return self.loc

    def median(self):
        # Számítjuk ki az eloszlásfüggvény mediánját
        return self.loc  # A medián megegyezik a várható értékkel a normális eloszlásban

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Az eloszlásfüggvény mediánjának lekérdezése
    distribution_median = normal_dist.median()
    print(f"Az eloszlás mediánja: {distribution_median}")

"""
21., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény varianciáját.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: variance
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        return self.loc

    def median(self):
        # Számítjuk ki az eloszlásfüggvény mediánját
        return self.loc  # A medián megegyezik a várható értékkel a normális eloszlásban

    def variance(self):
        # Számítjuk ki az eloszlásfüggvény varianciáját
        return self.scale ** 2

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Az eloszlásfüggvény varianciájának lekérdezése
    distribution_variance = normal_dist.variance()
    print(f"Az eloszlás varianciája: {distribution_variance}")

"""
22., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény ferdeségét.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: skewness
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        return self.loc

    def median(self):
        # Számítjuk ki az eloszlásfüggvény mediánját
        return self.loc  # A medián megegyezik a várható értékkel a normális eloszlásban

    def variance(self):
        # Számítjuk ki az eloszlásfüggvény varianciáját
        return self.scale ** 2

    def skewness(self):
        # Számítjuk ki az eloszlásfüggvény ferdeségét
        return 0.0  # A normális eloszlás ferdesége mindig 0

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Az eloszlásfüggvény ferdeségének lekérdezése
    distribution_skewness = normal_dist.skewness()
    print(f"Az eloszlás ferdesége: {distribution_skewness}")

"""
23., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény többlet csúcsosságát.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: ex_kurtosis
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        return self.loc

    def median(self):
        # Számítjuk ki az eloszlásfüggvény mediánját
        return self.loc  # A medián megegyezik a várható értékkel a normális eloszlásban

    def variance(self):
        # Számítjuk ki az eloszlásfüggvény varianciáját
        return self.scale ** 2

    def skewness(self):
        # Számítjuk ki az eloszlásfüggvény ferdeségét
        return 0.0  # A normális eloszlás ferdesége mindig 0

    def ex_kurtosis(self):
        # Számítjuk ki az eloszlásfüggvény többlet csúcsosságát
        return 0.0  # A normális eloszlás többlet csúcsossága mindig 0

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Az eloszlásfüggvény többlet csúcsosságának lekérdezése
    excess_kurtosis = normal_dist.ex_kurtosis()
    print(f"Az eloszlás többlet csúcsossága: {excess_kurtosis}")

"""
24., Egészítse ki a NormalDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény első 3 cetrális momentumát és a többlet csúcsosságot.  Ha az eloszlásnak nincsenek ilyen értékei, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: mvsk
    bemenet: None
    kimeneti típus: List
    link: https://en.wikipedia.org/wiki/Normal_distribution
"""
import scipy.stats as stats

class NormalDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Várható érték (location)
        self.scale = scale  # Szórás (scale)

    def pdf(self, x):
        # Számítjuk ki a normális eloszlás valószínűségi sűrűségfüggvényét
        coefficient = 1 / (self.scale * math.sqrt(2 * math.pi))
        exponent = -((x - self.loc) ** 2) / (2 * self.scale ** 2)
        probability_density = coefficient * math.exp(exponent)
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a normális eloszlás kumulatív eloszlásfüggvényét
        z = (x - self.loc) / self.scale
        cumulative_probability = (1 + math.erf(z / math.sqrt(2))) / 2
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki az eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        z = stats.norm.ppf(p)
        x = self.loc + z * self.scale
        return x

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        return self.loc

    def median(self):
        # Számítjuk ki az eloszlásfüggvény mediánját
        return self.loc  # A medián megegyezik a várható értékkel a normális eloszlásban

    def variance(self):
        # Számítjuk ki az eloszlásfüggvény varianciáját
        return self.scale ** 2

    def skewness(self):
        # Számítjuk ki az eloszlásfüggvény ferdeségét
        return 0.0  # A normális eloszlás ferdesége mindig 0

    def ex_kurtosis(self):
        # Számítjuk ki az eloszlásfüggvény többlet csúcsosságát
        return 0.0  # A normális eloszlás többlet csúcsossága mindig 0

    def mvsk(self):
        # Számítjuk ki az eloszlásfüggvény első 3 cetrális momentumát és többlet csúcsosságát
        mean = self.mean()
        variance = self.variance()
        skewness = self.skewness()
        kurtosis = 3.0  # A normális eloszlás kurtózisa mindig 3
        return [mean, variance, skewness, kurtosis]

# Tesztelés
if __name__ == "__main__":
    # Egy Normális eloszlás objektum létrehozása
    mean = 0  # Várható érték (location)
    std_dev = 1  # Szórás (scale)
    normal_dist = NormalDistribution(mean, std_dev)
    
    # Az eloszlásfüggvény első 3 cetrális momentumának lekérdezése
    mvsk_values = normal_dist.mvsk()
    print(f"Első 3 cetrális momentum és többlet csúcsosság: {mvsk_values}")
# Out:
# Várható érték: 0
# Szórás: 1
# Az x=1 értékhez tartozó valószínűségi sűrűség: 0.24197072451914337
# A kumulatív eloszlás értéke x=1.0 esetén: 0.8413447460685429
# Kvantilis a(z) p=0.7 esetén: 0.5244005127080407
# Normális eloszlású véletlen szám: 1.456623957492281
# Az eloszlás átlaga: 0
# Az eloszlás mediánja: 0
# Az eloszlás varianciája: 1
# Az eloszlás ferdesége: 0.0
# Az eloszlás többlet csúcsossága: 0.0
# Első 3 cetrális momentum és többlet csúcsosság: [0, 1, 0.0, 3.0]

# %%
"""
25., Hozzan létre egy új osztályt aminek a neve CauchyDistribution. Definiáljon benne a __init__ nevű függvényt, amelynek bemenetként kap egy véletlenszám generátort, az x0 (location) és gamma (scale) értékeket, amelyeket adattagokba ment le.
    Osztály név: CauchyDistribution
    függvény név: __init__
    bemenet: self, rand, loc, scale
"""
class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

"""
26., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely a bemeneti x értékhez hozzárendeli annak valószínűségi értékét
    függvény név: pdf
    bemenet: x
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    import random
    
    # Véletlenszám generátor létrehozása
    random_generator = random.Random()
    
    # CauchyDistribution objektum létrehozása
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    # Valószínűségi sűrűségfüggvény kiértékelése
    x_value = 1.0
    probability_density = cauchy_dist.pdf(x_value)
    print(f"Valószínűségi sűrűség az x={x_value} pontban: {probability_density}")

"""
27., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely megvalósítja az eloszlás kumulatív eloszlás függvényét.
    függvény név: cdf
    bemenet: x
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import math

class CauchyDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Középpont (location)
        self.scale = scale  # Skála (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        probability_density = (1 / (math.pi * self.scale)) * (1 / (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        cumulative_probability = (1 / math.pi) * math.atan((x - self.loc) / self.scale) + 0.5
        return cumulative_probability

    def ppf(self, p):
        # Implementálása a Cauchy-eloszlás inverz kumulatív eloszlásfüggvényének (nincs meghatározva)
        raise NotImplementedError("Az inverz kumulatív eloszlásfüggvény nincs definiálva a Cauchy-eloszlás esetében.")
# Create an instance of CauchyDistribution
center = 0  # Középpont (location)
scale = 1  # Skála (scale)
cauchy_dist = CauchyDistribution(center, scale)

# Test the cdf function
x_value = 1.0  # Tesztelendő érték
cumulative_probability = cauchy_dist.cdf(x_value)
print(f"Kumulatív eloszlásérték a(z) {x_value} értékhez: {cumulative_probability}")

"""
28., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely implementálja az eloszlás inverz kumulatív eloszlás függvényét
    függvény név: ppf
    bemenet: p
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import math

class CauchyDistribution:
    def __init__(self, loc, scale):
        self.loc = loc    # Középpont (location)
        self.scale = scale  # Skála (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        probability_density = (1 / (math.pi * self.scale)) * (1 / (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        cumulative_probability = (1 / math.pi) * math.atan((x - self.loc) / self.scale) + 0.5
        return cumulative_probability

    def ppf(self, p):
        # Számítjuk ki a Cauchy-eloszlás inverz kumulatív eloszlásfüggvényét
        if p < 0 or p > 1:
            raise ValueError("A p értéke 0 és 1 között kell, hogy legyen.")
        
        x = self.loc + self.scale * math.tan(math.pi * (p - 0.5))
        return x
# Create an instance of CauchyDistribution
center = 0  # Középpont (location)
scale = 1  # Skála (scale)
cauchy_dist = CauchyDistribution(center, scale)

# Test the ppf function
probability = 0.25  # Tesztelendő valószínűség
x_value = cauchy_dist.ppf(probability)
print(f"Inverz kumulatív eloszlásérték a(z) {probability} valószínűséghez: {x_value}")

"""
29., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely az osztály létrehozásánál megadott paraméterek mellett, cauchy eloszlású véletlen számokat generál minden meghívásnál
    függvény név: gen_random
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import random
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnak kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnak kell lennie.")
        
        cumulative_probability = 0.5 + (1 / math.pi) * math.atan((x - self.loc) / self.scale)
        return cumulative_probability

    def gen_random(self):
        # Generálunk egy Cauchy-eloszlású véletlen számot
        u = self.rand.random()  # Véletlenszerű szám az (0, 1) intervallumból
        random_number = self.loc + self.scale * math.tan(math.pi * (u - 0.5))
        return random_number

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    random_generator = random.Random()
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    # Cauchy-eloszlású véletlen szám generálása
    random_value = cauchy_dist.gen_random()
    print(f"Cauchy-eloszlású véletlen szám: {random_value}")

"""
30., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény átlagát. Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: mean
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import random
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        cumulative_probability = 0.5 + (1 / math.pi) * math.atan((x - self.loc) / self.scale)
        return cumulative_probability

    def gen_random(self):
        # Generálunk egy Cauchy-eloszlású véletlen számot
        u = self.rand.random()  # Véletlenszerű szám az (0, 1) intervallumból
        random_number = self.loc + self.scale * math.tan(math.pi * (u - 0.5))
        return random_number

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        raise Exception("Moment undefined")

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    random_generator = random.Random()
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    try:
        # Az eloszlásfüggvény átlagának lekérdezése
        mean_value = cauchy_dist.mean()
        print(f"Eloszlásfüggvény átlaga: {mean_value}")
    except Exception as e:
        print(f"Hiba: {e}")


"""
31., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény mediánját.
    függvény név: median
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import random
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        cumulative_probability = 0.5 + (1 / math.pi) * math.atan((x - self.loc) / self.scale)
        return cumulative_probability

    def gen_random(self):
        # Generálunk egy Cauchy-eloszlású véletlen számot
        u = self.rand.random()  # Véletlenszerű szám az (0, 1) intervallumból
        random_number = self.loc + self.scale * math.tan(math.pi * (u - 0.5))
        return random_number

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        raise Exception("Moment undefined")

    def median(self):
        # Az eloszlásfüggvény mediánja a lokáció értéke
        return self.loc

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    random_generator = random.Random()
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    # Az eloszlásfüggvény mediánjának lekérdezése
    median_value = cauchy_dist.median()
    print(f"Eloszlásfüggvény mediánja: {median_value}")

"""
32., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény varianciáját.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: variance
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import random
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnak kell lennie.")
        
        cumulative_probability = 0.5 + (1 / math.pi) * math.atan((x - self.loc) / self.scale)
        return cumulative_probability

    def gen_random(self):
        # Generálunk egy Cauchy-eloszlású véletlen számot
        u = self.rand.random()  # Véletlenszerű szám az (0, 1) intervallumból
        random_number = self.loc + self.scale * math.tan(math.pi * (u - 0.5))
        return random_number

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        raise Exception("Moment undefined")

    def median(self):
        # Az eloszlásfüggvény mediánja a lokáció értéke
        return self.loc

    def variance(self):
        # A Cauchy-eloszlásnak nincsen véges varianciája, ezért Exception-t dobunk
        raise Exception("Moment undefined")

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    random_generator = random.Random()
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    try:
        # Az eloszlásfüggvény varianciájának lekérdezése
        variance_value = cauchy_dist.variance()
        print(f"Eloszlásfüggvény varianciája: {variance_value}")
    except Exception as e:
        print(f"Hiba: {e}")

"""
33., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény ferdeségét.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: skewness
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import random
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnak kell lennie.")
        
        cumulative_probability = 0.5 + (1 / math.pi) * math.atan((x - self.loc) / self.scale)
        return cumulative_probability

    def gen_random(self):
        # Generálunk egy Cauchy-eloszlású véletlen számot
        u = self.rand.random()  # Véletlenszerű szám az (0, 1) intervallumból
        random_number = self.loc + self.scale * math.tan(math.pi * (u - 0.5))
        return random_number

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        raise Exception("Moment undefined")

    def median(self):
        # Az eloszlásfüggvény mediánja a lokáció értéke
        return self.loc

    def variance(self):
        # A Cauchy-eloszlásnak nincsen véges varianciája, ezért Exception-t dobunk
        raise Exception("Moment undefined")

    def skewness(self):
        # A Cauchy-eloszlásnak nincsen véges ferdesége, ezért Exception-t dobunk
        raise Exception("Moment undefined")

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    random_generator = random.Random()
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    try:
        # Az eloszlásfüggvény ferdeségének lekérdezése
        skewness_value = cauchy_dist.skewness()
        print(f"Eloszlásfüggvény ferdesége: {skewness_value}")
    except Exception as e:
        print(f"Hiba: {e}")

"""
34., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény többlet csúcsosságát.  Ha az eloszlásnak nincsen ilyen értéke, akkor return helyett hívja meg a raise Exception("Moment undefined") parancsot.
    függvény név: ex_kurtosis
    bemenet: None
    kimeneti típus: float
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import random
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnak kell lennie.")
        
        cumulative_probability = 0.5 + (1 / math.pi) * math.atan((x - self.loc) / self.scale)
        return cumulative_probability

    def gen_random(self):
        # Generálunk egy Cauchy-eloszlású véletlen számot
        u = self.rand.random()  # Véletlenszerű szám az (0, 1) intervallumból
        random_number = self.loc + self.scale * math.tan(math.pi * (u - 0.5))
        return random_number

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        raise Exception("Moment undefined")

    def median(self):
        # Az eloszlásfüggvény mediánja a lokáció értéke
        return self.loc

    def variance(self):
        # A Cauchy-eloszlásnak nincsen véges varianciája, ezért Exception-t dobunk
        raise Exception("Moment undefined")

    def skewness(self):
        # A Cauchy-eloszlásnak nincsen véges ferdesége, ezért Exception-t dobunk
        raise Exception("Moment undefined")

    def ex_kurtosis(self):
        # A Cauchy-eloszlásnak nincs véges többlet csúcsossága, ezért Exception-t dobunk
        raise Exception("Moment undefined")

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    random_generator = random.Random()
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    try:
        # Az eloszlásfüggvény többlet csúcsosságának lekérdezése
        ex_kurtosis_value = cauchy_dist.ex_kurtosis()
        print(f"Eloszlásfüggvény többlet csúcsossága: {ex_kurtosis_value}")
    except Exception as e:
        print(f"Hiba: {e}")

"""
35., Egészítse ki a CauchyDistribution osztályt egy új függvénnyel, amely visszaadja az eloszlás függvény első 3 cetrális momentumát és a többlet csúcsosságot.  Ha az eloszlásnak nincsenek ilyen értékei, akkor return helyett hívja meg a raise Exception("Moments undefined") parancsot.
    függvény név: mvsk
    bemenet: None
    kimeneti típus: List
    link: https://en.wikipedia.org/wiki/Cauchy_distribution
"""
import random
import math

class CauchyDistribution:
    def __init__(self, rand, loc, scale):
        self.rand = rand  # Véletlenszám generátor
        self.loc = loc    # x0 (location)
        self.scale = scale  # gamma (scale)

    def pdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás valószínűségi sűrűségfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnek kell lennie.")
        
        probability_density = 1 / (math.pi * self.scale * (1 + ((x - self.loc) / self.scale) ** 2))
        return probability_density

    def cdf(self, x):
        # Számítjuk ki a Cauchy-eloszlás kumulatív eloszlásfüggvényét
        if self.scale <= 0:
            raise ValueError("A skála (scale) értéke pozitívnak kell lennie.")
        
        cumulative_probability = 0.5 + (1 / math.pi) * math.atan((x - self.loc) / self.scale)
        return cumulative_probability

    def gen_random(self):
        # Generálunk egy Cauchy-eloszlású véletlen számot
        u = self.rand.random()  # Véletlenszerű szám az (0, 1) intervallumból
        random_number = self.loc + self.scale * math.tan(math.pi * (u - 0.5))
        return random_number

    def mean(self):
        # Számítjuk ki az eloszlásfüggvény átlagát
        raise Exception("Moments undefined")

    def median(self):
        # Az eloszlásfüggvény mediánja a lokáció értéke
        return self.loc

    def variance(self):
        # A Cauchy-eloszlásnak nincsen véges varianciája, ezért Exception-t dobunk
        raise Exception("Moments undefined")

    def skewness(self):
        # A Cauchy-eloszlásnak nincsen véges ferdesége, ezért Exception-t dobunk
        raise Exception("Moments undefined")

    def ex_kurtosis(self):
        # A Cauchy-eloszlásnak nincs véges többlet csúcsossága, ezért Exception-t dobunk
        raise Exception("Moments undefined")

    def mvsk(self):
        # A Cauchy-eloszlásnak nincsenek véges cetrális momentumai és többlet csúcsossága, ezért Exception-t dobunk
        raise Exception("Moments undefined")

# Tesztelés
if __name__ == "__main__":
    # Példa az osztály használatára
    random_generator = random.Random()
    location = 0  # x0 (location)
    scale = 1  # gamma (scale)
    cauchy_dist = CauchyDistribution(random_generator, location, scale)
    
    try:
        # Az eloszlásfüggvény első 3 cetrális momentumának lekérdezése
        mvsk_values = cauchy_dist.mvsk()
        print(f"Első 3 cetrális momentum és többlet csúcsosság: {mvsk_values}")
    except Exception as e:
        print(f"Hiba: {e}")
# Out:
# Valószínűségi sűrűség az x=1.0 pontban: 0.15915494309189535
# Kumulatív eloszlásérték a(z) 1.0 értékhez: 0.75
# Inverz kumulatív eloszlásérték a(z) 0.25 valószínűséghez: -0.9999999999999999
# Cauchy-eloszlású véletlen szám: 5.571248935927364
# Hiba: Moment undefined
# Eloszlásfüggvény mediánja: 0
# Hiba: Moment undefined
# Hiba: Moment undefined
# Hiba: Moment undefined
# Hiba: Moments undefined
